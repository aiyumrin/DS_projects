# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Импортируем-все-необходимые-библиотеки." data-toc-modified-id="Импортируем-все-необходимые-библиотеки.-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импортируем все необходимые библиотеки.</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Проверка-эффективности-обогащения" data-toc-modified-id="Проверка-эффективности-обогащения-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Проверка эффективности обогащения</a></span></li><li><span><a href="#Признаки-не-доступные-в-тестовой-выборке" data-toc-modified-id="Признаки-не-доступные-в-тестовой-выборке-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Признаки не доступные в тестовой выборке</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Работа-с-пропусками" data-toc-modified-id="Работа-с-пропусками-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Работа с пропусками</a></span></li></ul></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Концентрация-металлов-на-разных-стадиях-обогащения" data-toc-modified-id="Концентрация-металлов-на-разных-стадиях-обогащения-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Концентрация металлов на разных стадиях обогащения</a></span></li><li><span><a href="#Распределение-размеров-гранул" data-toc-modified-id="Распределение-размеров-гранул-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Распределение размеров гранул</a></span></li><li><span><a href="#Суммарная-концентрация-веществ-на-разных-стадиях" data-toc-modified-id="Суммарная-концентрация-веществ-на-разных-стадиях-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Суммарная концентрация веществ на разных стадиях</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Выбор-модели-для-флотации" data-toc-modified-id="Выбор-модели-для-флотации-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Выбор модели для флотации</a></span></li><li><span><a href="#Выбор-модели-для-финальной-очистки." data-toc-modified-id="Выбор-модели-для-финальной-очистки.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Выбор модели для финальной очистки.</a></span></li><li><span><a href="#Проверка-на-тестовых-данных" data-toc-modified-id="Проверка-на-тестовых-данных-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Проверка на тестовых данных</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.

# %% [markdown]
# ## Технологический процесс

# %% [markdown]
# Когда добытая руда проходит первичную обработку, получается дроблёная смесь. Её отправляют на флотацию (обогащение) и двухэтапную очистку.
#
# #### Флотация
# Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов.
# На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).
# #### Очистка
# Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.
#
#
#
# ## Метрика качества
#
# Для решения задачи введём метрику качества — sMAPE (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).
# Она похожа на MAE, но выражается не в абсолютных величинах, а в относительных. Почему симметричная? Она одинаково учитывает масштаб и целевого признака, и предсказания.
# Метрика sMAPE вычисляется так:
# $$sMAPE=\frac{1}{N}\sum_{i=1}^N\frac{|y_i - \hat y_i|}{(|y_i|+|\hat y_i|)/2}$$
# - $y$ - значение целевого признака
# - $\hat y$ - значение предсказания
# - $N$ - количество объектов в выборке
#
# Нужно спрогнозировать сразу две величины:
#
# - эффективность обогащения чернового концентрата `rougher.output.recovery`;
# - эффективность обогащения финального концентрата `final.output.recovery`.
#
# Итоговая метрика складывается из двух величин:
#
# $$sMAPE_{итоговое}=0.25*{sMAPE}(rougher) + 0.75*{sMAPE}(final)$$

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Импортируем все необходимые библиотеки.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.metrics import mean_absolute_error
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.dummy import DummyRegressor
from sklearn import linear_model
import warnings
warnings.filterwarnings("ignore")
from numpy import arange 
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

# %% [markdown]
# ### Загрузка данных

# %% [markdown]
# Загрузим данные и сохраним их в переменных.

# %%
try:
    df_train = pd.read_csv('')
    df_test = pd.read_csv('')
    df_full = pd.read_csv('')  
except:
    df_train = pd.read_csv('https://')
    df_test = pd.read_csv('https://')
    df_full = pd.read_csv('https://')

# %% [markdown]
# Рассмотрим первые строки и основную информацию о загруженных данных.

# %%
display(df_train.head())
df_train.info()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
display(df_test.head())
df_test.info()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %%
display(df_full.head())
df_full.info()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %% [markdown]
# Данные сформировались корректно.

# %% [markdown]
# ### Проверка эффективности обогащения

# %% [markdown]
# Проверим правильность расчета эффективности обогащения на этапе флотации. Рассчитаем эффективность для обучающей выборки и сравним с имеющейся.

# %%
rougher_rec_calc = df_train['rougher.output.concentrate_au'] * (
    df_train['rougher.input.feed_au'] - df_train['rougher.output.tail_au']
) / (df_train['rougher.input.feed_au'] * (df_train['rougher.output.concentrate_au'] - df_train['rougher.output.tail_au'])) * 1e2

# %% [markdown]
# Рассчитаем MAE для имевшихся и полученных значений эффективности.

# %%
mean_absolute_error(rougher_rec_calc, df_train['rougher.output.recovery'])
# Out:
# 9.73512347450521e-15

# %% [markdown]
# Полученное значение MAE близко к нулю. Можем сделать вывод о том, что имевшиеся ранее и полученные при расчетах данные совпадают.

# %% [markdown]
# ### Признаки не доступные в тестовой выборке

# %% [markdown]
# Рассмотрим признаки имеющиеся в обучающей выборке и не доступные в тестовой.

# %%
columns_dif = df_train.columns.drop(df_test.columns)
df_train[columns_dif].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14149 entries, 0 to 14148
# Data columns (total 34 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.concentrate_ag                         14148 non-null  float64
#  1   final.output.concentrate_pb                         14148 non-null  float64
#  2   final.output.concentrate_sol                        13938 non-null  float64
#  3   final.output.concentrate_au                         14149 non-null  float64
#  4   final.output.recovery                               14149 non-null  float64
#  5   final.output.tail_ag                                14149 non-null  float64
#  6   final.output.tail_pb                                14049 non-null  float64
#  7   final.output.tail_sol                               14144 non-null  float64
# ...

# %% [markdown]
# В тестовой выборке отсутствуют следующие признаки доступные в обучающей:
# - По этапу флотации
#     - Расчетные данные
#     - Параметры продукта
#         - Концентрация металлов в продукте флотации
#         - Концентрация металлов в отвальных хвостах после флотации
#     - Эффективность обогащения чернового концентрата
# - По первому этапу очистки
#     - Параметры продукта
#         - Концентрация металлов в продукте первого этапа
#         - Концентрация металлов в отвальных хвостах после первого этапа
# - По второму этапу очистки
#     - Параметры продукта
#         - Концентрация металлов в отвальных хвостах после второго этапа
# - По финальным характеристикам
#     - Параметры продукта
#         - Концентрация металлов в финальном продукте
#         - Концентрация металлов в отвальных хвостах
#     - Эффективность обогащения финального концентрата

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# В тестовых данных отсутствуют параметры, которые становятся доступны только после обогащения. Исключим эти параметры и из обучающей выборки.

# %%
df_train = df_train.drop(columns_dif.drop(['rougher.output.recovery', 'final.output.recovery']), axis=1)

# %%
display(df_train.shape)
display(df_test.shape)
# Out:
# (14149, 55)
# (5290, 53)

# %% [markdown]
# #### Работа с пропусками

# %% [markdown]
# Выведем количество пропусков для каждого столбца тестовой выборки.

# %%
df_test.isna().sum()
# Out:
# date                                           0
# primary_cleaner.input.sulfate                  4
# primary_cleaner.input.depressant               5
# primary_cleaner.input.feed_size                0
# primary_cleaner.input.xanthate                 4
# primary_cleaner.state.floatbank8_a_air         0
# primary_cleaner.state.floatbank8_a_level       0
# primary_cleaner.state.floatbank8_b_air         0
# primary_cleaner.state.floatbank8_b_level       0
# primary_cleaner.state.floatbank8_c_air         0
# primary_cleaner.state.floatbank8_c_level       0
# primary_cleaner.state.floatbank8_d_air         0
# primary_cleaner.state.floatbank8_d_level       0
# rougher.input.feed_ag                          0
# rougher.input.feed_pb                          0
# rougher.input.feed_rate                        3
# rougher.input.feed_size                        1
# rougher.input.feed_sol                        21
# rougher.input.feed_au                          0
# ...

# %% [markdown]
# Так как все наблюдения представляют собой последовательные измерения заполним пропуски в тестовых данных методом интерполяции.

# %%
df_test = df_test.bfill().ffill()

# %% [markdown]
# Выведем количество пропусков для каждого столбца обучающей выборки.

# %%
df_train.isna().sum()
# Out:
# date                                            0
# final.output.recovery                           0
# primary_cleaner.input.sulfate                  20
# primary_cleaner.input.depressant               32
# primary_cleaner.input.feed_size                 0
# primary_cleaner.input.xanthate                100
# primary_cleaner.state.floatbank8_a_air          4
# primary_cleaner.state.floatbank8_a_level        1
# primary_cleaner.state.floatbank8_b_air          4
# primary_cleaner.state.floatbank8_b_level        1
# primary_cleaner.state.floatbank8_c_air          2
# primary_cleaner.state.floatbank8_c_level        1
# primary_cleaner.state.floatbank8_d_air          3
# primary_cleaner.state.floatbank8_d_level        1
# rougher.input.feed_ag                           0
# rougher.input.feed_pb                         100
# rougher.input.feed_rate                         8
# rougher.input.feed_size                       144
# rougher.input.feed_sol                         78
# ...

# %% [markdown]
# Для восстановления пропущенных данных рассмотрим зависимости параметров друг от друга.

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df_train.corr());

# %% [markdown]
# Наибольшее количество ппропусков в столбце `rougher.input.floatbank11_xanthate`. По тепловой карте можем заметить сильную корелляцию этого параметра с параметром `rougher.input.floatbank10_xanthate`. Рассмотрим зависимость подробнее.

# %%
def line(col_1, col_2):
    fig, ax = plt.subplots(figsize=(15, 5))
    p = sns.regplot(x=df_train[col_2], 
                y=df_train[col_1], 
                line_kws={"color":"r","alpha":0.7,"lw":5}
               )
    p
    plt.show()
    x = p.get_lines()[0].get_xdata()
    y = p.get_lines()[0].get_ydata()
    global b
    global k
    b = (y[-2]*x[1] - y[1]*x[-2])/(x[1]-x[-2])
    k = (y[1] - b) / x[1]
    print(k, b)

line('rougher.input.floatbank11_xanthate', 'rougher.input.floatbank10_xanthate')
# Out:
# 0.9763609625501802 0.14453793182216226

# %% [markdown]
# В основном значения параметра `rougher.input.floatbank11_xanthate` совпадают со значениями параметра `rougher.input.floatbank10_xanthate`. Заполним пропущенные значения значениями из `rougher.input.floatbank10_xanthate`.

# %%
df_train['rougher.input.floatbank11_xanthate'] = df_train['rougher.input.floatbank11_xanthate'].fillna(
    df_train['rougher.input.floatbank10_xanthate'] * k + b
)
print(k, b)
# Out:
# 0.9763609625501802 0.14453793182216226

# %%
line('rougher.state.floatbank10_e_air', 'rougher.state.floatbank10_f_air')
# Out:
# 0.9959268582022937 52.99154104854384

# %%
df_train['rougher.state.floatbank10_e_air'] = df_train['rougher.state.floatbank10_e_air'].fillna(
    df_train['rougher.input.floatbank10_xanthate'] * k + b
)
print(k, b)
# Out:
# 0.9959268582022937 52.99154104854384

# %%
line('secondary_cleaner.state.floatbank2_a_air', 'secondary_cleaner.state.floatbank2_b_air')
# Out:
# 0.8507576409333175 8.473232376981622

# %%
df_train['secondary_cleaner.state.floatbank2_a_air'] = df_train['secondary_cleaner.state.floatbank2_a_air'].fillna(
    df_train['secondary_cleaner.state.floatbank2_b_air'] * k + b
)
print(k, b)
# Out:
# 0.8507576409333175 8.473232376981622

# %%
a = df_train.shape[0]
df_train = df_train.dropna()
print('Осталось', df_train.shape[0] / a *100, '% данных от df_train')
# Out:
# Осталось 96.58633118948336 % данных от df_train

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Концентрация металлов на разных стадиях обогащения

# %% [markdown]
# Рассмотрим средние значения концентрации металлов на разных этапах.

# %%
rougher_input_columns = [
    'rougher.input.feed_ag', 
    'rougher.input.feed_pb', 
    'rougher.input.feed_sol', 
    'rougher.input.feed_au'
]
rougher_output_columns = [
    'rougher.output.concentrate_ag', 
    'rougher.output.concentrate_pb', 
    'rougher.output.concentrate_sol', 
    'rougher.output.concentrate_au'
]
primary_cleaner_output_columns = [
    'primary_cleaner.output.concentrate_ag',
    'primary_cleaner.output.concentrate_pb',
    'primary_cleaner.output.concentrate_sol',
    'primary_cleaner.output.concentrate_au'
]
final_output_columns = [
    'final.output.concentrate_ag',
    'final.output.concentrate_pb',
    'final.output.concentrate_sol',
    'final.output.concentrate_au'
]
columns = [rougher_input_columns, rougher_output_columns, primary_cleaner_output_columns, final_output_columns]

met = []
stage = []
for m in range(4):
    for s in range(4):
        stage.append(df_full[columns[m][s]].mean())
    met.append(stage)
    stage = []
    
met = pd.DataFrame(
    met, index=['rougher_input', 'rougher_output', 'primary', 'final'], 
    columns=['ag', 'pb', 'sol', 'au']
).drop('sol', axis=1)
display(met)
met.plot(figsize=(15, 5), marker='o');
# Out:
#                        ag        pb         au
# rougher_input    8.794927  3.598085   8.266097
# rougher_output  11.994759  7.606272  19.772000
# primary          8.442408  9.829530  32.119400
# final            5.168470  9.978895  44.076513

# %% [markdown]
# Концентрация золота в руде увеличивается после каждой стадии обогащения. Концентрация свинца тоже растет. Скорее всего это является результатом того, что золото и свинец при обогащении руды находятся в связанном состоянии и при обогащении они не разделяются. Концентрация серебра после стадии флотации увеличивается, а при дальнейшей переработке начинает снижаться.

# %% [markdown]
# ### Распределение размеров гранул

# %% [markdown]
# Рассмотрим распределения  размеров гранул сырья на обучающей и тестовой выборках.

# %%
sns.set(rc={'figure.figsize':(15, 5)})
sns.kdeplot(data=df_test, x='rougher.input.feed_size')
sns.kdeplot(data=df_train, x='rougher.input.feed_size');

# %% [markdown]
# Распределения размеров сырья в тестовой и обучающей выборках отличаются не сильно. Наиболее часто встречающиеся размеры находятся в одном диапазоне.

# %% [markdown]
# ### Суммарная концентрация веществ на разных стадиях

# %%
df_full['rougher.input_sum'] = df_full[columns[0]].sum(axis=1)
df_full['rougher.output_sum'] = df_full[columns[1]].sum(axis=1)
df_full['primary_cleaner.output_sum'] = df_full[columns[2]].sum(axis=1)
df_full['final.output_sum'] = df_full[columns[3]].sum(axis=1)

sns.histplot(data=df_full, x='rougher.input_sum');

# %%
sns.histplot(data=df_full, x='rougher.output_sum');

# %%
sns.histplot(data=df_full, x='primary_cleaner.output_sum');

# %%
sns.histplot(data=df_full, x='final.output_sum');

# %% [markdown]
# На гистограммах распределения суммарной концентрации наблюдается большое количество нулевых значений. Устраним эти аномалии из полной выборки.

# %%
for col in ['rougher.input_sum', 'rougher.output_sum', 'primary_cleaner.output_sum', 'final.output_sum']:
    df_full = df_full.loc[df_full[col]>.1]

sns.histplot(data=df_full, x='rougher.input_sum')
sns.histplot(data=df_full, x='rougher.output_sum')
sns.histplot(data=df_full, x='primary_cleaner.output_sum')
sns.histplot(data=df_full, x='final.output_sum');

# %%
df_train = df_train.set_index('date')
df_test = df_test.set_index('date')
df_full = df_full.set_index('date')
df_train = df_train.loc[df_train.index.isin(df_full.index)]
df_test = df_test.loc[df_test.index.isin(df_full.index)]

# %% [markdown]
# ## Модель

# %% [markdown]
# Выделим признаки из обучающей выборки и шкалируем их.

# %%
df_features_f = df_train.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)
scaler = StandardScaler()
scaler.fit(df_features_f)

def feature_target_split(data):
    rougher_features_columns = [
        'rougher.input.feed_ag',
        'rougher.input.feed_pb',
        'rougher.input.feed_rate',
        'rougher.input.feed_size',
        'rougher.input.feed_sol',
        'rougher.input.feed_au',
        'rougher.input.floatbank10_sulfate',
        'rougher.input.floatbank10_xanthate',
        'rougher.input.floatbank11_sulfate',
        'rougher.input.floatbank11_xanthate',
        'rougher.state.floatbank10_a_air',
        'rougher.state.floatbank10_a_level',
        'rougher.state.floatbank10_b_air',
        'rougher.state.floatbank10_b_level',
        'rougher.state.floatbank10_c_air',
        'rougher.state.floatbank10_c_level',
        'rougher.state.floatbank10_d_air',
        'rougher.state.floatbank10_d_level',
        'rougher.state.floatbank10_e_air',
        'rougher.state.floatbank10_e_level',
        'rougher.state.floatbank10_f_air',
        'rougher.state.floatbank10_f_level'
    ]

    df_target_r = data['rougher.output.recovery']
    df_target_f = data['final.output.recovery']

    df_features_f = data.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)
    df_features_f = pd.DataFrame(scaler.transform(df_features_f), index=df_features_f.index, columns=df_features_f.columns)

    df_features_r = df_features_f[rougher_features_columns]
    return df_features_r, df_target_r, df_features_f, df_target_f

df_features_r, df_target_r, df_features_f, df_target_f = feature_target_split(df_train)

# %% [markdown]
# Введем функцию для подсчета sMAPE.

# %%
def smape(target, predict):
    return sum(abs(target - predict) / ((abs(target) + abs(predict)) / 2) * 100) / len(predict)

def smape_final(smape_r, smape_f):
    return .25 * smape_r + .75 * smape_f

# %% [markdown]
# Введем функцию для оценки моделей кросс-валидацией.

# %%
def cross_val(model, n, features, target):
    scores = []
    sample_size = int(len(features)/n)
    for i in range(0, len(features), sample_size):
        valid_indexes = features[i:i+sample_size].index
        train_indexes = features.index.drop(valid_indexes)
    
        features_train = features.loc[train_indexes]
        target_train = target.loc[train_indexes]
        features_valid = features.loc[valid_indexes]
        target_valid = target.loc[valid_indexes]

        model.fit(features_train, target_train)
        predictions = model.predict(features_valid) + 1e-15
    
        score = smape(target_valid, predictions)
        scores.append(score)


    scores.pop(-1)
    final_score = sum(scores) / len(scores)
    return final_score, model

# %% [markdown]
# ### Выбор модели для флотации

# %% [markdown]
# Оценим различные модели для этапа флотации метрикой sMAPE.

# %%
cross_val(LinearRegression(), 5, df_features_r, df_target_r)
# Out:
# (6.891720021595593, LinearRegression())

# %%
cross_val(DecisionTreeRegressor(random_state=765), 5, df_features_r, df_target_r)
# Out:
# (8.269879987965961, DecisionTreeRegressor(random_state=765))

# %%
cross_val(linear_model.Lasso(alpha=0.5), 5, df_features_r, df_target_r)
# Out:
# (6.193533927267536, Lasso(alpha=0.5))

# %%
#cross_val(RandomForestRegressor(random_state=765), 5, df_features_r, df_target_r)

# %%
cross_val(linear_model.ElasticNet(alpha=1.0, random_state=765), 5, df_features_r, df_target_r)
# Out:
# (6.138661374613947, ElasticNet(random_state=765))

# %% [markdown]
# Наилучшие значения sMAPE получили для модели ElasticNet. Подберем для нее гиперпараметры.

# %%
def hyper_params(features, target, alpha, tol, selection):
    scorer = make_scorer(smape, greater_is_better=False)
    parameters = {'alpha': alpha,
                  'tol': tol,
                  'selection': selection}

    grid = GridSearchCV(linear_model.ElasticNet(random_state=765), parameters, scoring=scorer, cv=5)
    grid.fit(features, target)
    display(grid.best_estimator_)
    display(
        pd.DataFrame(grid.cv_results_)[
            ['param_alpha', 'param_tol', 'param_selection', 'mean_test_score', 'rank_test_score']
        ].sort_values('rank_test_score').head()
    )
    
    
    return grid.best_estimator_
    
best_model_r = hyper_params(df_features_r, df_target_r, arange(.3, .6, .1), arange(.0017, .002, .0001), ['cyclic', 'random'])
#Для экономии времени сузил диапазоны значений гиперпараметров после нахождения наилучшего сочетания.
# Out:
# ElasticNet(alpha=0.4, random_state=765, selection='random', tol=0.0017)
#    param_alpha param_tol param_selection  mean_test_score  rank_test_score
# 12         0.4    0.0017          random        -6.035971                1
# 13         0.4    0.0018          random        -6.035971                1
# 15         0.4     0.002          random        -6.036179                3
# 14         0.4    0.0019          random        -6.036220                4
# 20         0.5    0.0017          random        -6.036377                5

# %% [markdown]
# ### Выбор модели для финальной очистки.

# %% [markdown]
# Оценим различные модели для финальной очистки метрикой sMAPE.

# %%
cross_val(LinearRegression(), 5, df_features_f, df_target_f)
# Out:
# (10.66159106618202, LinearRegression())

# %%
cross_val(DecisionTreeRegressor(random_state=765), 5, df_features_f, df_target_f)
# Out:
# (15.304710912349739, DecisionTreeRegressor(random_state=765))

# %%
cross_val(linear_model.Lasso(alpha=.5), 5, df_features_f, df_target_f)
# Out:
# (8.918778311463324, Lasso(alpha=0.5))

# %%
#cross_val(RandomForestRegressor(random_state=765), 5, df_features_f, df_target_f)

# %%
cross_val(linear_model.ElasticNet(alpha=1.0, random_state=765), 5, df_features_f, df_target_f)
# Out:
# (8.848580130397622, ElasticNet(random_state=765))

# %% [markdown]
# Наилучшие значения sMAPE получили для модели ElasticNet. Подберем для нее гиперпараметры.

# %%
best_model_f = hyper_params(df_features_f, df_target_f, arange(.5, .8, .1), arange(.0012, .0015, .0001), ['cyclic', 'random'])
# Out:
# ElasticNet(alpha=0.6, random_state=765, selection='random', tol=0.0013)
#    param_alpha param_tol param_selection  mean_test_score  rank_test_score
# 14         0.6    0.0014          random        -8.796569                1
# 13         0.6    0.0013          random        -8.796569                1
# 15         0.6    0.0015          random        -8.796636                3
# 12         0.6    0.0012          random        -8.796855                4
# 8          0.6    0.0012          cyclic        -8.797607                5

# %% [markdown]
# Обучим модели с наилучшими sMAPE на тренировочных данных.

# %%
best_model_r.fit(df_features_r, df_target_r)
best_model_f.fit(df_features_f, df_target_f)
# Out:
# ElasticNet(alpha=0.6, random_state=765, selection='random', tol=0.0013)

# %% [markdown]
# ### Проверка на тестовых данных

# %% [markdown]
# Из общих данных подтянем целевые признаки к тренировочным данным. Выделим признаки и шкалируем их.

# %%
df_test = df_test.merge(
    df_full[['rougher.output.recovery', 'final.output.recovery']], 
    how='inner',  
    left_index=True, 
    right_index=True
)
df_features_full_r, df_target_full_r, df_features_full_f, df_target_full_f = feature_target_split(df_test)

# %% [markdown]
# Оценим модели на тестовых данных.

# %%
predictions_full_r = best_model_r.predict(df_features_full_r)
predictions_full_f = best_model_f.predict(df_features_full_f)
smape_full_r = smape(df_target_full_r, predictions_full_r)
smape_full_f = smape(df_target_full_f, predictions_full_f)
print('sMAPE на тестовой выборке:', smape_final(smape_full_r, smape_full_f))
# Out:
# sMAPE на тестовой выборке: 6.542482962943289

# %% [markdown]
# Сравним полученную оценку с оценкой константных моделей.

# %%
dummy_regr = DummyRegressor(strategy='mean')
dummy_regr.fit(df_features_full_r, df_target_full_r)
median_r = dummy_regr.predict(df_features_full_r)
dummy_regr.fit(df_features_full_f, df_target_full_f)
median_f = dummy_regr.predict(df_features_full_f)

smape_const_r = smape(df_target_full_r, median_r)
smape_const_f = smape(df_target_full_f, median_f)
print('sMAPE на константной модели:', smape_final(smape_const_r, smape_const_f))
# Out:
# sMAPE на константной модели: 6.849373526938928

# %%
plt.plot(df_target_full_r.values)
plt.plot(predictions_full_r)
plt.plot(median_r);

# %% [markdown]
# ## Вывод

# %% [markdown]
# В этом проекте были отработаны несколько моментов. А самый очевидный: заметно, что разность метрик качества (константной и нашей модели) -  не слишком большая. Такое расхождение метрик допустимо в этом проекте. Для улучшения качества моделирования необходимо учесть следующее:
#
# 1. Качество данных на входе модели машинного обучения: повторно оценить аномалии, пропуски, соответствие законам химии и физики, все ли правдоподобно?
# 2. Работа с моделями машинного обучения:
# - Создание новых признаков для моделей, Features Engineering: возможно стоит обратиться к технологу производства и ещё раз пробежаться по бизнес-цепочке процесса.
# - Отбор самих моделей машинного обучения и гиперпараметров.
#
# 3. Параметры производственного процесса, к примеру: температура сырья, скорость ленточного конвейера, и.т.п.
#
#
# Если провести Анализ измерительных систем, или MSA, то можно разобраться в причинах неточности полученных с производства данных. Статистический анализ данных, или SPC, - тоже будет являться незаменимым помощником в решении нашей задачи.
#
# Цель нашего проекта достигнута, а именно пройдены важные этапы подготовки данных и построения модели для производства золота.
